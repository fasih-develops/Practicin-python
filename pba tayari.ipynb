# %%
name  = "Ali"
height = 7.8
age  = 15
your_age=  int(input("Enter your age"))
print(name, height, age)
# Out:
# Enter your age 78
# Ali 7.8 15

# %%
a = 14
b = 2
print("here is the ramainder", a%b )
print("here the result after taking exponent", a**b)
print("is a greater than b:", a<b)
print("is a equal to b:", a==b)

x = True 
y = False
print(x and y)
print(not x)
# Out:
# here is the ramainder 0
# here the result after taking exponent 196
# is a greater than b: False
# is a equal to b: False
# False
# False
