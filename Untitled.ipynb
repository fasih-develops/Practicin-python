# %%
num = int(input("Enter an integer: "))

factorial = 1

for i in range(1, num + 1):
    factorial = factorial*i

print("Factorial =", factorial)
# Out:
# Enter an integer:  6
# Factorial = 720

# %%
def factorial(n):
    face = 1
    for i in range(1, num+1):
        fact= fact*i
    return fact

num = int(input())
