# %%
with open("char.txt", "r") as f:
    for char in f.read():
        print(char, end="")
# Out:
# WE WILL MISS YOU RED DEAD REDEMPTION 2 GAMEPLAY LIVE

# %%
try:
    with open("char.txt", "r") as f:
        for char in f.read():
            print(char,end="")
except fojlfjs:
    print("fs")
# Out:
# WE WILL MISS YOU RED DEAD REDEMPTION 2 GAMEPLAY LIVE
