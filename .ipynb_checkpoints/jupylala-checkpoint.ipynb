# %%
with open("jupy.txt", "w") as f:
    f.write("salam alaikum\n")

f.close()

# %%
with open("jupy.txt", "r+") as f:
    text = f.read()
print(text)
# Out:
# salam alaikum

# %%
# Open the file in read mode
with open("char.txt", "r") as file:
    # Read the entire content
    text = file.read()

# Print the content
print(text)
# Out:
# WE WILL MISS YOU RED DEAD REDEMPTION 2 GAMEPLAY LIVE
